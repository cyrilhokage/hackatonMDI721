# %%
import pandas as pd

df = pd.read_excel("bp_review_2018.xlsx")

df
# Out:
#       BP Statistical Review of World Energy June 2019
# 0    This workbook contains information presented ...
# 1    BP Statistical Review of World Energy, which ...
# 2                                        internet at:
# 3                 http://www.bp.com/statisticalreview
# 4   Please use the contents or the tabs at the bot...
# 5      Primary Energy: Consumption - Mtoe (from 1965)
# 6   Primary Energy: Consumption by fuel type - Mto...
# 7   Primary Energy: Consumption per capita - Gigaj...
# 8                                Oil: Proved reserves
# 9          Oil: Proved reserves - Barrels (from 1980)
# 10              Oil: Production - Barrels (from 1965)
# 11               Oil: Production - Tonnes (from 1965)
# 12  Oil: Crude oil and condensate production - Bar...
# 13  Oil: Natural Gas Liquids production - Barrels ...
# 14             Oil: Consumption - Barrels (from 1965)
# 15              Oil: Consumption - Tonnes (from 1965)
# ...
